# %%
import kagglehub 
import seaborn as sns
import pandas as pd 
import os 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib
import array 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt 
import statistics

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mlesa'

# %%
path = os.chdir(r"C:\Users\mlesa\OneDrive\Desktop\download files")

# %%
path

# %%
df = pd.read_csv("Student_Performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df['Extracurricular Activities'].replace({'No':0, 'Yes':1}, inplace = True )

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
for x in x.items():
    plt.figure()
    plt.hist(x, edgecolor = 'black')
    plt.xlabel('variable')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for x in x.items():
#       2     plt.figure()
#       3     plt.hist(x, edgecolor = 'black')
#
# NameError: name 'x' is not defined

# %%
plt.hist(df['Performance Index'], color= 'blue', edgecolor = 'black')
plt.show()

# %%
plt.hist(df['Sleep Hours'], color= 'blue', edgecolor = 'black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['Previous Scores'], color = 'red', edgecolor = 'black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
statistics.mean(df['Performance Index'])
# Out:
# 55.2248

# %%
statistics.median(df['Performance Index'])
# Out:
# 55.0

# %%
y = df['Performance Index']

# %%
print(y)
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
x = df.drop(columns = 'Performance Index')

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Train_MSE = mean_absolute_error(y_train, model.predict (x_train))

# %%
print(f"Training MSE is: {Train_MSE}")
# Out:
# Training MSE is: 1.6183900872912582

# %%
Test_MSE = mean_absolute_error(y_test, model.predict(x_test))

# %%
print(f"test MSE is: {Test_MSE}")
# Out:
# test MSE is: 1.6143639019116067

# %%
model.predict(x)
# Out:
# array([91.82453993, 63.15555129, 45.03523466, ..., 72.97334242,
#        94.34820431, 65.28912421])

# %%
Y_predict = model.predict(x)

# %%
residuals = y - Y_predict

# %%
residuals
# Out:
# 0      -0.824540
# 1       1.844449
# 2      -0.035235
# 3      -0.534271
# 4      -1.082861
#           ...
# 9995    1.417390
# 9996    1.521331
# 9997    1.026658
# 9998    0.651796
# 9999   -1.289124
# Name: Performance Index, Length: 10000, dtype: float64
